# %%
import pandas as pd
import numpy as np

# %%
path = "D:\\THANH PHƯƠNG\\University\\Python for DA\\Pandas,numpy,matplotlib\\heart_disease_dataset.csv"

df = pd.read_csv(path)
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
#
# [4238 rows x 16 columns]

# %%
df = df.fillna(method='ffill')

# %%
# df.head(10)

# %%
import matplotlib
from matplotlib import pyplot as plt
plt.hist(df.education, bins=20, edgecolor='black')
plt.xlabel('education')
plt.ylabel('Count')
plt.show()

# %%
# df.education.describe().round(2)

# %%
# Q1 = df.education.quantile(0.25)
# Q3 = df.education.quantile(0.75)
# Q2 = df.education.quantile(0.5)
# Q1,Q3,Q2
# df.education.min()

# %%
# IQR = Q3 - Q1
# IQR

# %%
# lower_limit = Q1 - 1.5*IQR
# upper_limit = Q3 + 1.5*IQR
# lower_limit,upper_limit

# %%
# class math_operations():
#     def __init__(self,cin_cols):
#         self.cin_cols = cin_cols
#     def statistic_figures(self):
#         return self.cin_cols.describe().round(3)
    
# using_col = df.totChol
# main = math_operations(using_col)
# main.statistic_figures()

# %%
# num_of_classes = 1 + np.log2(4238)
# num_of_classes

# %%
n = 10
dataset = df.head(int(len(df)*(n/100)))
dataset
# Out:
#      male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0       1   39        4.0              0         0.0     0.0                0
# 1       0   46        2.0              0         0.0     0.0                0
# 2       1   48        1.0              1        20.0     0.0                0
# 3       0   61        3.0              1        30.0     0.0                0
# 4       0   46        3.0              1        23.0     0.0                0
# ..    ...  ...        ...            ...         ...     ...              ...
# 418     1   37        3.0              1        30.0     0.0                0
# 419     0   52        1.0              1        25.0     0.0                0
# 420     0   46        2.0              0         0.0     0.0                0
# 421     1   44        1.0              0         0.0     0.0                0
# 422     0   42        2.0              1        15.0     0.0                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0               0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1               0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2               0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3               1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4               0         0    285.0  130.0   84.0  23.10       85.0     85.0
# ..            ...       ...      ...    ...    ...    ...        ...      ...
# 418             0         0    243.0  128.0   84.0  27.47       80.0     72.0
# 419             0         0    235.0  119.0   82.0  24.25       77.0     79.0
# 420             0         0    232.0   90.0   60.0  19.20       60.0     82.0
# 421             0         1    190.0  122.0   81.0  36.12       70.0    143.0
# 422             0         0    177.0  112.5   70.0  20.62       86.0     83.0
#
#      TenYearCHD
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ..          ...
# 418           0
# 419           0
# 420           0
# 421           0
# 422           0
#
# [423 rows x 16 columns]

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = df.cigsPerDay
y = df.age

plt.scatter(x,y)
plt.xlabel("cigPerDay")
plt.ylabel("age")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\THINK\AppData\Local\Temp\ipykernel_7956\1010682982.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn')
#plot1
x = df.cigsPerDay.where(df.male == 1).dropna()
y = df.heartRate.where(df.male == 1).dropna()

#plt.subplot(row,cols,oder)
plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel("cigsPerDay")
plt.ylabel("hearRate")
plt.title("male")
#plot2
x = df.cigsPerDay.where(df.male == 0).dropna()
y = df.heartRate.where(df.male == 0).dropna()

plt.subplot(1,2,2)
plt.scatter(x,y)
plt.xlabel("cigsPerDay")
plt.ylabel("hearRate")
plt.title("female")

plt.suptitle("ciggerate and heart rate")
plt.show()
# Out:
# C:\Users\THINK\AppData\Local\Temp\ipykernel_7956\1732616869.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn')

n = 500
#plot1
x = df.age.where(df.male == 1).dropna().head(n)
y = df.heartRate.where(df.male == 1).dropna().head(n)

#plt.subplot(row,cols,oder)
plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel("age")
plt.ylabel("hearRate")
plt.title("male")
#plot2
x = df.age.where(df.male == 0).dropna().head(n)
y = df.heartRate.where(df.male == 0).dropna().head(n)

plt.subplot(1,2,2)
plt.scatter(x,y)
plt.xlabel("age")
plt.ylabel("hearRate")
plt.title("female")

plt.suptitle("age and heart rate")
plt.show()
# Out:
# C:\Users\THINK\AppData\Local\Temp\ipykernel_7956\31097304.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
### Research at each gender who smoke have will cause heart disease
## caculate conifence interval
# Get the sample of smoking male caused heart disease 
n_male = df.heartRate[(df.male == 1) & (df.cigsPerDay != 0)].head(1000)
n_male
# Out:
# 2       75.0
# 9       93.0
# 12      98.0
# 16      64.0
# 24      75.0
#         ...
# 3845    60.0
# 3848    80.0
# 3850    69.0
# 3851    70.0
# 3856    63.0
# Name: heartRate, Length: 1000, dtype: float64

# %%
# get the mean,std value
meanv = n_male.describe().round(3)
meanv
# Out:
# count    1000.000
# mean       75.288
# std        11.565
# min        45.000
# 25%        67.000
# 50%        75.000
# 75%        81.250
# max       120.000
# Name: heartRate, dtype: float64

# %%
# Choosing the confident of 95% --> t_df = 0.95/2 = 0.475 ~~ 1.96
# Caculating the standard var

range_v = (11.565/np.sqrt(1000)).round(3)
range_v
# Out:
# 0.366

# %%
# Get the confident interval
lower_limit = (75.517 - 1.96*range_v).round(3)
higher_limit = (75.517 + 1.96*range_v).round(3)
print(f"Confident interval: ({lower_limit};{higher_limit})")
# Out:
# Confident interval: (74.8;76.234)

# %%
Q1 = n_male.quantile(0.25)
Q3 = n_male.quantile(0.75)
Q1, Q3
# Out:
# (67.0, 81.25)

# %%
# var_no_smoking = 12.203 **2
# var_smoking = 11.801 ** 2
# var_no_smoking, var_smoking

# %%
# Z_statistics = (75.194 - 76.584)/(np.sqrt((var_no_smoking/2157) + (var_smoking/2081)))
# Z_statistics

# %%
# The degree of freedom
# t_df = ((var_no_smoking/2157) + (var_smoking/2081)) / (((var_no_smoking/2157)**2 / (2157-1)) + ((var_smoking/2081)**2 / (2081-1)))
# t_df(var_no_smoking/2157)**2 / (2157-1)
