# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "D:\\THANH PHƯƠNG\\University\\Python for DA\\Pandas,numpy,matplotlib\\sales2019_1.csv"
data = pd.read_csv(path)

data
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
#incase make data wrong
backup_data = data

# %%
data = backup_data

# %%
data = data.dropna()

# %%
saled_lap = data.loc[data.Product.str.contains("Laptop")]
saled_monitor = data.loc[data.Product.str.contains("Monitor")]
saled_others = data.loc[(data.Product.str.contains("Monitor") == False) & \
                        (data.Product.str.contains("Laptop") == False)]
saled_others
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 0      141234                      iPhone                1        700
# 1      141235    Lightning Charging Cable                1      14.95
# 2      141236            Wired Headphones                2      11.99
# 4      141238            Wired Headphones                1      11.99
# 5      141239      AAA Batteries (4-pack)                1       2.99
# ...       ...                         ...              ...        ...
# 9715   150494      AAA Batteries (4-pack)                1       2.99
# 9716   150495  Bose SoundSport Headphones                1      99.99
# 9717   150496  Bose SoundSport Headphones                1      99.99
# 9721   150500      AAA Batteries (4-pack)                2       2.99
# 9722   150501                Google Phone                1        600
#
#           Order Date                        Purchase Address
# 0     01/22/19 21:25         944 Walnut St, Boston, MA 02215
# ...

# %%
data["Product"].value_counts()
# Out:
# USB-C Charging Cable          1171
# AAA Batteries (4-pack)        1082
# Lightning Charging Cable      1068
# AA Batteries (4-pack)         1039
# Wired Headphones              1005
# Apple Airpods Headphones       809
# Bose SoundSport Headphones     656
# 27in FHD Monitor               418
# iPhone                         379
# Google Phone                   317
# 34in Ultrawide Monitor         313
# 27in 4K Gaming Monitor         312
# Flatscreen TV                  243
# Macbook Pro Laptop             235
# ThinkPad Laptop                216
# 20in Monitor                   213
# Vareebadd Phone                124
# LG Washing Machine              42
# LG Dryer                        39
# Product                         16
# Name: Product, dtype: int64

# %%
fdf = data.drop(data[data["Product"] == "Product"].index)
fdf
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
fdf["Product"].value_counts()
# Out:
# USB-C Charging Cable          1171
# AAA Batteries (4-pack)        1082
# Lightning Charging Cable      1068
# AA Batteries (4-pack)         1039
# Wired Headphones              1005
# Apple Airpods Headphones       809
# Bose SoundSport Headphones     656
# 27in FHD Monitor               418
# iPhone                         379
# Google Phone                   317
# 34in Ultrawide Monitor         313
# 27in 4K Gaming Monitor         312
# Flatscreen TV                  243
# Macbook Pro Laptop             235
# ThinkPad Laptop                216
# 20in Monitor                   213
# Vareebadd Phone                124
# LG Washing Machine              42
# LG Dryer                        39
# Name: Product, dtype: int64

# %%
plt.style.use("fivethirtyeight")
plt.hist(fdf["Product"], bins= 19, orientation="horizontal", edgecolor='black', label = "Amoun of each products")
plt.ylabel("Amount")
plt.xlabel("Goods")
plt.legend()
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 plt.style.use("fivethirtyeight")
#       2 plt.hist(fdf["Product"], bins= 19, orientation="horizontal", edgecolor='black', label = "Amoun of each products")
# ----> 3 plt.ylabel("Amount")
#       4 plt.xlabel("Goods")
#       5 plt.legend()
#
# TypeError: 'str' object is not callable

# %%
fdf["Order Date"].values
# Out:
# array(['01/22/19 21:25', '01/28/19 14:15', '01/17/19 13:33', ...,
#        '01/21/19 14:31', '01/15/19 14:21', '01/13/19 16:43'], dtype=object)

# %%
fdf["Order Date"] = pd.to_datetime(fdf["Order Date"]).dt.strftime("%d/%m/%Y %H:%M")
fdf["Order Date"]
# Out:
# 0       22/01/2019 21:25
# 1       28/01/2019 14:15
# 2       17/01/2019 13:33
# 3       05/01/2019 20:33
# 4       25/01/2019 11:59
#               ...
# 9718    26/01/2019 19:09
# 9719    10/01/2019 22:58
# 9720    21/01/2019 14:31
# 9721    15/01/2019 14:21
# 9722    13/01/2019 16:43
# Name: Order Date, Length: 9681, dtype: object

# %%
plt.scatter(fdf["Product"], fdf["Price Each"])
plt.xlabel = "Product"
plt.ylabel = "Price"
plt.show()

# %%
df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
                  [6.4, 3.2, 1], [5.9, 3.0, 2]],
                   columns=['length', 'width', 'species'])
ax1 = df.plot.scatter(x='length',
                       y='width',
                      c = "species",
                      colormap='viridis')
plt.show()

# %%
df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
                  [6.4, 3.2, 1], [5.9, 3.0, 2]],
                  columns=['length', 'width', 'species'])
df
# Out:
#    length  width  species
# 0     5.1    3.5        0
# 1     4.9    3.0        0
# 2     7.0    3.2        1
# 3     6.4    3.2        1
# 4     5.9    3.0        2

# %%
import seaborn as sns
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
for col in 'xy':
    sns.kdeplot(data[col], shade=True)
# Out:
# C:\Users\THINK\AppData\Local\Temp\ipykernel_8960\1804397067.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
# C:\Users\THINK\AppData\Local\Temp\ipykernel_8960\1804397067.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[col], shade=True)
